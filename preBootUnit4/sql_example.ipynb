# %% [markdown]
# # A simple postgres to pandas example

# %% [markdown]
# First we import SymPy and initialize printing:

# %%
from sympy import init_printing
import pandas as pd
from sympy import *
import json
import psycopg2
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
with open('../../postge_local.jsn') as f:
    conf = json.load(f)
    conn_str = "host={} dbname={} user={} password={}".format(conf['host'],conf['database'],conf['user'],conf['passw'])
    # get a connection, if a connect cannot be made an exception will be raised here
conn = psycopg2.connect(conn_str)

# %%
cursor = conn.cursor()

# %%
duration = pd.read_sql('select * from trips', con=conn)
#dr=duration[:999]

# %%
# 1 var -> 4 plots
sns.set_style('whitegrid')
sns.boxplot(data=dr, x='duration')
plt.show()

# %%
sns.set(style="whitegrid", palette="pastel", color_codes=True)

sns.distplot(dr,hist=True );
plt.show()

# %%
sns.rugplot(dr, color=".2", linewidth=3);
plt.show()

# %%
dr.hist(figsize = (10,10))
plt.show()
