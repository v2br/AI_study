# %% [markdown]
# * Choose one variable and plot that variable four different ways.
# * 1 var -> 4 plots
# * * 1.1 -> histogram
# * * 1.2 -> distplot
# * * 1.3 -> fitting parametric distribution?
# * * 1.4 -> kernel density
#
#
# * Choose two continuous variables, and plot them three different ways.
# * 2 vars ->3 ways
#
#
# g = sns.lmplot('final_sec', 'split_frac', col='gender', data=data,
#                markers=".", scatter_kws=dict(color='c'))
#
# Pairplots & Correlation
#
#
# * Choose one continuous variable and one categorical variable, and plot them six different ways.
#
#
# * 1 cont var, 1 cat -> 6 ways

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
print(tips.head(n=4))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
sns.set(color_codes=True)

# %%
x=tips['tip']
sns.displot(x);

# %% [markdown]
# ### Histogram

# %%
sns.displot(x, kde=True, rug=True);

# %%
sns.kdeplot(x, bw=0.3, label="bw: 0.1", shade=True)
# Out:
# /home/vad/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.3 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.rugplot(x, color=".3", linewidth=3);
plt.show()

# %%
sns.boxplot(data=x)
# Out:
# <AxesSubplot:>

# %%
sns.swarmplot(data=x)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 2 vars
#
# ####
# * * 2.1 -> sns.kdeplot(data)
# * * 2.2 -> sns.pairplot
# * * 2.3 -> sns.factorplot
# * * 2.4 -> sns.jointplot

# %%
bill_tips=tips.drop(['day','time','smoker','size','sex'], axis=1)
plt.legend('Tips and toal bill')
sns.kdeplot(bill_tips, legend=True )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a91274857a9c> in <module>
#       1 bill_tips=tips.drop(['day','time','smoker','size','sex'], axis=1)
#       2 plt.legend('Tips and toal bill')
# ----> 3 sns.kdeplot(bill_tips, legend=True )
#
# ~/miniconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.pairplot(tips, hue='day', size=2.5);
# Out:
# /home/vad/miniconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Joint Distribution Plot
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.swarmplot(x='total_bill', y='tip', data= tips)
# Out:
# /home/vad/miniconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/vad/miniconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
g = sns.factorplot(x='day', 
                   y='tip', 
                   data=tips, 
                   hue='sex',  # Color by stage
                   col='sex',  # Separate by stage
                   kind='swarm') # Swarmplot
 
# Rotate x-axis labels
g.set_xticklabels(rotation=-45)
plt.show()
# Out:
# /home/vad/miniconda3/lib/python3.8/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
g = sns.factorplot(x='day', 
                   y='tip', 
                   data=tips, 
                   hue='sex',  # Color by stage
                   col='sex',  # Separate by stage
                   kind='box') # box
 
# Rotate x-axis labels
g.set_xticklabels(rotation=-45)
plt.show()
# Out:
# /home/vad/miniconda3/lib/python3.8/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
g = sns.factorplot(x='day', 
                   y='tip', 
                   data=tips, 
                   hue='sex',  # Color by stage
                   col='sex',  # Separate by stage
                   kind='violin') #  
 
# Rotate x-axis labels
g.set_xticklabels(rotation=-45)
plt.show()

# %%
g = sns.factorplot(x='day', 
                   y='tip', 
                   data=tips, 
                   hue='sex',  # Color by stage
                   col='sex',  # Separate by stage
                   kind='strip') # box
 
# Rotate x-axis labels
g.set_xticklabels(rotation=-45)
plt.show()

# %%
sns.swarmplot(x='day', y='tip', data=tips)

# %%
sns.catplot(x='day', y='tip', data=tips)

# %%
# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(x="day", y="total_bill", hue="smoker",
               split=True, inner="quart",
               palette={"Yes": "y", "No": "b"},
               data=tips)
sns.despine(left=True)
